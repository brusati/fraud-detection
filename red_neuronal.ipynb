# %% [markdown]
# #Cuestiones generales

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %% [markdown]
# #Train set

# %% [markdown]
# Descargo y leo los csv

# %%
id = '1VvZp2MML5dLce79TMsrCQm5VkvQn93zN'
downloaded = drive.CreateFile({'id': id})
downloaded.GetContentFile('train_identity.csv')

train_identity = pd.read_csv('train_identity.csv')

# %%
id = '18ZAaojp_783CfnqhNj43w1vgwZOH221D'
downloaded = drive.CreateFile({'id': id})
downloaded.GetContentFile('train_transaction.csv')

train_transaction = pd.read_csv('train_transaction.csv')

# %% [markdown]
# Mergeo los dos datasets que tengo

# %%
df = pd.merge(train_transaction, train_identity, on='TransactionID', how='left')

# %%
df.head(10)
# Out:
#    TransactionID  isFraud  ...  DeviceType                     DeviceInfo
# 0        2987000        0  ...         NaN                            NaN
# 1        2987001        0  ...         NaN                            NaN
# 2        2987002        0  ...         NaN                            NaN
# 3        2987003        0  ...         NaN                            NaN
# 4        2987004        0  ...      mobile  SAMSUNG SM-G892A Build/NRD90M
# 5        2987005        0  ...         NaN                            NaN
# 6        2987006        0  ...         NaN                            NaN
# 7        2987007        0  ...         NaN                            NaN
# 8        2987008        0  ...      mobile                     iOS Device
# 9        2987009        0  ...         NaN                            NaN
#
# [10 rows x 434 columns]

# %% [markdown]
# Limpio la RAM

# %%
train_transaction = None
train_identity = None
downloaded = None

# %% [markdown]
# #Validation set

# %% [markdown]
# Dejo un 30% del dataset original como validation set

# %%
len(df.index)
# Out:
# 590540

# %%
validation = df.loc[0:(0.3 * len(df.index)), :]

# %%
len(validation.index)
# Out:
# 177163

# %%
train = df.loc[(0.3 * len(df.index)):len(df.index), :]

# %%
len(train.index)
# Out:
# 413378

# %%
train.head(10)
# Out:
#         TransactionID  isFraud  TransactionDT  ...  id_38 DeviceType  DeviceInfo
# 177162        3164162        0        3864166  ...    NaN        NaN         NaN
# 177163        3164163        1        3864195  ...    NaN        NaN         NaN
# 177164        3164164        0        3864205  ...    NaN        NaN         NaN
# 177165        3164165        1        3864212  ...    NaN        NaN         NaN
# 177166        3164166        0        3864218  ...    NaN        NaN         NaN
# 177167        3164167        0        3864222  ...    NaN        NaN         NaN
# 177168        3164168        0        3864228  ...    NaN        NaN         NaN
# 177169        3164169        0        3864242  ...    NaN        NaN         NaN
# 177170        3164170        0        3864249  ...    NaN        NaN         NaN
# 177171        3164171        0        3864277  ...    NaN        NaN         NaN
#
# [10 rows x 434 columns]

# %%
validation.head(10)
# Out:
#    TransactionID  isFraud  ...  DeviceType                     DeviceInfo
# 0        2987000        0  ...         NaN                            NaN
# 1        2987001        0  ...         NaN                            NaN
# 2        2987002        0  ...         NaN                            NaN
# 3        2987003        0  ...         NaN                            NaN
# 4        2987004        0  ...      mobile  SAMSUNG SM-G892A Build/NRD90M
# 5        2987005        0  ...         NaN                            NaN
# 6        2987006        0  ...         NaN                            NaN
# 7        2987007        0  ...         NaN                            NaN
# 8        2987008        0  ...      mobile                     iOS Device
# 9        2987009        0  ...         NaN                            NaN
#
# [10 rows x 434 columns]

# %%
columnas_train = train.columns

# %% [markdown]
# Limpio la RAM

# %%
df = None

# %% [markdown]
# #Encoding train y validation set

# %%
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# Diccionario en el que guardo como claves las columnas y como valores una lista de la forma [encoder, mean]

# %%
dic = {}

# %%
for c in train.columns:
  if c == 'isFraud': #a la columna isFraud no la toco
      continue

  if c == 'id_31': #aplico CountVectorizer a la columna id_30
      from sklearn.feature_extraction.text import CountVectorizer
      vectorizer = CountVectorizer(max_features=7)
      train[c].fillna(' ', inplace=True)
      vectorizer.fit(train.id_31)

      feature = vectorizer.transform(train.id_31).toarray()
      new_df = pd.DataFrame(feature, columns=vectorizer.get_feature_names(), index=train.index)
      train = pd.concat([train, new_df], axis=1).drop(columns=[c])

      validation[c].fillna(' ', inplace=True)
      feature = vectorizer.transform(validation.id_31).toarray()
      new_df = pd.DataFrame(feature, columns=vectorizer.get_feature_names(), index=validation.index)
      validation = pd.concat([validation, new_df], axis=1).drop(columns=[c])

      dic[c] = [vectorizer, None]

      vectorizer = None
      feature = None
      feature_labels = None
      new_df = None

      continue


  if c == 'DeviceType': #aplico OneHotEncoding a las columnas ProductCD y card4
      ohe = OneHotEncoder()
      ohe.fit(train[[c]])

      feature = ohe.transform(train[[c]]).toarray()
      new_df = pd.DataFrame(feature, columns=ohe.categories_, index=train.index)
      train = pd.concat([train, new_df], axis=1).drop(columns=[c])

      feature = ohe.transform(validation[[c]]).toarray()
      new_df = pd.DataFrame(feature, columns=ohe.categories_, index=validation.index)
      validation = pd.concat([validation, new_df], axis=1).drop(columns=[c])

      dic[c] = [ohe, None]

      ohe = None
      feature = None
      feature_labels = None
      new_df = None

      continue

  if (train[c].dtype.kind not in 'biufc'): #aplico MeanEncoding al resto de las columnas no numéricas
      mean_encoded_subject = train.groupby(c)['isFraud'].mean().to_dict()

      train[c] =  train[c].map(mean_encoded_subject)
      validation[c] = validation[c].map(mean_encoded_subject)

      dic[c] = [mean_encoded_subject, train[c].mean()]

  aux = train[c].mean()
  train[c].fillna(aux, inplace=True)
  validation[c].fillna(aux, inplace=True)
  if c not in dic:
    dic[c] = [None, aux]
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
train.head(10)
# Out:
#         TransactionID  isFraud  TransactionDT  ...  (desktop,)  (mobile,)  (nan,)
# 177162        3164162        0        3864166  ...         0.0        0.0     1.0
# 177163        3164163        1        3864195  ...         0.0        0.0     1.0
# 177164        3164164        0        3864205  ...         0.0        0.0     1.0
# 177165        3164165        1        3864212  ...         0.0        0.0     1.0
# 177166        3164166        0        3864218  ...         0.0        0.0     1.0
# 177167        3164167        0        3864222  ...         0.0        0.0     1.0
# 177168        3164168        0        3864228  ...         0.0        0.0     1.0
# 177169        3164169        0        3864242  ...         0.0        0.0     1.0
# 177170        3164170        0        3864249  ...         0.0        0.0     1.0
# 177171        3164171        0        3864277  ...         0.0        0.0     1.0
#
# [10 rows x 442 columns]

# %%
validation.head(10)
# Out:
#    TransactionID  isFraud  TransactionDT  ...  (desktop,)  (mobile,)  (nan,)
# 0        2987000        0          86400  ...         0.0        0.0     1.0
# 1        2987001        0          86401  ...         0.0        0.0     1.0
# 2        2987002        0          86469  ...         0.0        0.0     1.0
# 3        2987003        0          86499  ...         0.0        0.0     1.0
# 4        2987004        0          86506  ...         0.0        1.0     0.0
# 5        2987005        0          86510  ...         0.0        0.0     1.0
# 6        2987006        0          86522  ...         0.0        0.0     1.0
# 7        2987007        0          86529  ...         0.0        0.0     1.0
# 8        2987008        0          86535  ...         0.0        1.0     0.0
# 9        2987009        0          86536  ...         0.0        0.0     1.0
#
# [10 rows x 442 columns]

# %% [markdown]
# #Feature Selection

# %%
from sklearn.feature_selection import SelectKBest, f_regression

# %%
points_train = train.drop(columns=['isFraud'])
labels_train = pd.DataFrame(train['isFraud'])

# %%
selector = SelectKBest(f_regression, k=100)

# %%
selector.fit(points_train, labels_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1679: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'tuple']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SelectKBest(k=100, score_func=<function f_regression at 0x7f3266b1b4d0>)

# %%
cols = selector.get_support(indices=True)

# %%
cols
# Out:
# array([  3,   6,   9,  15,  22,  27,  48,  68,  69,  70,  71,  74,  75,
#         76,  84,  85,  86,  87,  90,  91,  92,  93,  95,  96,  97,  98,
#        100, 103, 104, 105, 110, 111, 112, 113, 116, 117, 124, 125, 126,
#        127, 130, 131, 132, 133, 134, 137, 138, 139, 140, 145, 146, 147,
#        164, 166, 176, 202, 209, 211, 223, 224, 229, 239, 241, 242, 243,
#        244, 247, 250, 252, 253, 254, 274, 275, 281, 282, 283, 295, 296,
#        297, 298, 299, 300, 301, 302, 305, 307, 310, 311, 312, 315, 335,
#        336, 355, 356, 357, 430, 432, 433, 439, 440])

# %%
columnas_para_seleccionar = points_train.columns
l = []

# %%
cont = -1
for c in columnas_para_seleccionar:
  cont += 1
  if cont not in cols and c not in ['id_33', 'DeviceInfo', 'isFraud']:
    l.append(c)

train.drop(columns=l, inplace=True)

# %%
train.head()
# Out:
#         isFraud  ProductCD  card3     card6  ...  android  chrome  (mobile,)  (nan,)
# 177162        0   0.021053  150.0  0.025510  ...        0       0        0.0     1.0
# 177163        1   0.021053  150.0  0.025510  ...        0       0        0.0     1.0
# 177164        0   0.021053  150.0  0.025510  ...        0       0        0.0     1.0
# 177165        1   0.021053  150.0  0.025510  ...        0       0        0.0     1.0
# 177166        0   0.021053  150.0  0.080659  ...        0       0        0.0     1.0
#
# [5 rows x 102 columns]

# %%
cont = -1
for c in columnas_para_seleccionar:
  cont += 1
  if cont not in cols and c not in ['id_33', 'DeviceInfo', 'isFraud']:
    validation.drop(columns=[c], inplace=True)

# %%
validation.head()
# Out:
#    isFraud  ProductCD  card3     card6  ...  android  chrome  (mobile,)  (nan,)
# 0        0   0.021053  150.0  0.080659  ...        0       0        0.0     1.0
# 1        0   0.021053  150.0  0.080659  ...        0       0        0.0     1.0
# 2        0   0.021053  150.0  0.025510  ...        0       0        0.0     1.0
# 3        0   0.021053  150.0  0.025510  ...        0       0        0.0     1.0
# 4        0   0.095829  150.0  0.080659  ...        0       0        1.0     0.0
#
# [5 rows x 102 columns]

# %%
points_train = None
points_label = None
selector = None

# %% [markdown]
# #Keras Red Neuronal

# %% [markdown]
# Separo labels y points en train set

# %%
points_train = train.drop(columns=['isFraud'])
labels_train = pd.DataFrame(train['isFraud'])

# %% [markdown]
# Utilizo la librería sklearn para hacer un random forest regression con los mejores parámetros posibles

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf
from keras.metrics import AUC
from tensorflow.keras.optimizers import Adam

# %%
tf.random.set_seed(0)

# %%
red_neuronal = Sequential()
red_neuronal.add(Dense(100, input_dim=101, activation='relu'))
red_neuronal.add(Dense(50, activation='relu'))
red_neuronal.add(Dense(1, activation='sigmoid'))

red_neuronal.compile(loss='binary_crossentropy', optimizer=Adam(), metrics=[AUC()])

# %%
red_neuronal.fit(points_train, labels_train, epochs=3)
# Out:
# Epoch 1/3
# 12919/12919 [==============================] - 30s 2ms/step - loss: 0.1337 - auc: 0.7608
# Epoch 2/3
# 12919/12919 [==============================] - 27s 2ms/step - loss: 0.1173 - auc: 0.7986
# Epoch 3/3
# 12919/12919 [==============================] - 27s 2ms/step - loss: 0.1151 - auc: 0.8046

# %%
from sklearn.metrics import roc_auc_score

# %%
points_validation = validation.drop(columns=['isFraud'])
labels_validation = pd.DataFrame(validation['isFraud'])

# %%
roc_auc_score(labels_validation, red_neuronal.predict(points_validation))
# Out:
# 0.7451567117318507

# %% [markdown]
# #Libero la RAM

# %%
train = None
validation = None
points_train = None
points_validation = None
labels_train = None
labels_validation = None

# %% [markdown]
# #Test set

# %%
id = '11-pP9l-0FTW9A1pwrb2nVeAoV8Awf4oY'
downloaded = drive.CreateFile({'id': id})
downloaded.GetContentFile('test_transaction.csv')

test_transaction = pd.read_csv('test_transaction.csv')

# %%
id = '1xHLcsTe2619N38GI9O9QzPV74XRrUKbx'
downloaded = drive.CreateFile({'id': id})
downloaded.GetContentFile('test_identity.csv')

test_identity = pd.read_csv('test_identity.csv')

# %%
downloaded = None

# %% [markdown]
# Mergeo los dos datasets que tengo

# %%
df_test = pd.merge(test_transaction, test_identity, on='TransactionID', how='left')

# %%
test_transaction = None
test_identity = None

# %%
df_test.head(10)
# Out:
#    TransactionID  TransactionDT  TransactionAmt  ... id-38  DeviceType  DeviceInfo
# 0        3663549       18403224           31.95  ...   NaN         NaN         NaN
# 1        3663550       18403263           49.00  ...   NaN         NaN         NaN
# 2        3663551       18403310          171.00  ...   NaN         NaN         NaN
# 3        3663552       18403310          284.95  ...   NaN         NaN         NaN
# 4        3663553       18403317           67.95  ...   NaN         NaN         NaN
# 5        3663554       18403323           57.95  ...   NaN         NaN         NaN
# 6        3663555       18403350           87.00  ...   NaN         NaN         NaN
# 7        3663556       18403387          390.00  ...   NaN         NaN         NaN
# 8        3663557       18403405          103.95  ...   NaN         NaN         NaN
# 9        3663558       18403416          117.00  ...   NaN         NaN         NaN
#
# [10 rows x 433 columns]

# %%
ids = df_test[['TransactionID']]

# %% [markdown]
# #Me aseguro que las columnas de test sean las mismas que las de train

# %%
columnas = columnas_train.drop('isFraud')

# %%
df_test.columns = columnas

# %%
df_test.columns
# Out:
# Index(['TransactionID', 'TransactionDT', 'TransactionAmt', 'ProductCD',
#        'card1', 'card2', 'card3', 'card4', 'card5', 'card6',
#        ...
#        'id_31', 'id_32', 'id_33', 'id_34', 'id_35', 'id_36', 'id_37', 'id_38',
#        'DeviceType', 'DeviceInfo'],
#       dtype='object', length=433)

# %%
columnas = None

# %% [markdown]
# #Encoding test set

# %%
vectorizer = dic['id_31'][0]
df_test['id_31'].fillna(' ', inplace=True)

feature = vectorizer.transform(df_test.id_31).toarray()
new_df = pd.DataFrame(feature, columns=vectorizer.get_feature_names(), index=df_test.index)
df_test.drop(columns=['id_31'], inplace=True)
for i in new_df.columns:
  df_test[i] = new_df[i]

vectorizer = None
feature = None
feature_labels = None
new_df = None
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
ohe = dic['DeviceType'][0]

feature = ohe.transform(df_test[['DeviceType']]).toarray()
new_df = pd.DataFrame(feature, columns=ohe.categories_, index=df_test.index)
df_test.drop(columns=['DeviceType'], inplace=True)
for i in new_df.columns:
  df_test[i] = new_df[i]

ohe = None
feature = None
feature_labels = None
new_df = None

# %%
for c in columnas_train.drop('isFraud'):
    if c == 'id_31':
      continue

    if c == 'DeviceType':
      continue

    if (df_test[c].dtype.kind not in 'biufc'): #si no es numérica la columna
      mean_encoded_subject = dic[c][0]

      df_test[c] = df_test[c].map(mean_encoded_subject)

      mean_encoded_subject = None

    aux = dic[c][1]
    if aux:
      df_test[c].fillna(aux, inplace=True)

# %%
df_test.head(10)
# Out:
#    TransactionID  TransactionDT  TransactionAmt  ...  (desktop,)  (mobile,)  (nan,)
# 0        3663549       18403224           31.95  ...         0.0        0.0     1.0
# 1        3663550       18403263           49.00  ...         0.0        0.0     1.0
# 2        3663551       18403310          171.00  ...         0.0        0.0     1.0
# 3        3663552       18403310          284.95  ...         0.0        0.0     1.0
# 4        3663553       18403317           67.95  ...         0.0        0.0     1.0
# 5        3663554       18403323           57.95  ...         0.0        0.0     1.0
# 6        3663555       18403350           87.00  ...         0.0        0.0     1.0
# 7        3663556       18403387          390.00  ...         0.0        0.0     1.0
# 8        3663557       18403405          103.95  ...         0.0        0.0     1.0
# 9        3663558       18403416          117.00  ...         0.0        0.0     1.0
#
# [10 rows x 441 columns]

# %%
dic = None

# %% [markdown]
# #Elimino columnas test set

# %%
df_test.drop(columns=l, inplace=True)

# %% [markdown]
# #Predicciones

# %% [markdown]
# Este fue el mejor modelo así que lo envío a la competencia

# %%
df_predictions = pd.DataFrame(list(red_neuronal.predict(df_test)))

# %%
df_predictions['TransactionID'] = ids

# %%
df_predictions.columns = ['isFraud', 'TransactionID']

# %%
df_predictions.head(10)
# Out:
#     isFraud  TransactionID
# 0  0.009402        3663549
# 1  0.009472        3663550
# 2  0.006620        3663551
# 3  0.014094        3663552
# 4  0.010237        3663553
# 5  0.010237        3663554
# 6  0.009980        3663555
# 7  0.022919        3663556
# 8  0.006153        3663557
# 9  0.010975        3663558

# %%
df_predictions = df_predictions[['TransactionID', 'isFraud']]

# %%
df_predictions.head(10)
# Out:
#    TransactionID   isFraud
# 0        3663549  0.009402
# 1        3663550  0.009472
# 2        3663551  0.006620
# 3        3663552  0.014094
# 4        3663553  0.010237
# 5        3663554  0.010237
# 6        3663555  0.009980
# 7        3663556  0.022919
# 8        3663557  0.006153
# 9        3663558  0.010975

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
df_predictions.to_csv('RED_NEURONAL.csv', index=False)
# !cp RED_NEURONAL.csv "drive/My Drive/"

# %% [markdown]
# El score obtenido en la competencia es 0.845010
